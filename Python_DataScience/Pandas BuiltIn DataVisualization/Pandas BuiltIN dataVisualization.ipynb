# %%
import numpy as np 
import seaborn as sns

# %%
import pandas as pd

# %%
# %matplotlib inline

# %%
pwd
# Out:
# 'C:\\Users\\ckp43_000\\Py_DS_CKP\\Python_DataScience\\Pandas BuiltIn DataVisualization'

# %%
df1=pd.read_csv('D:/DataScience_Udemy/Py_DS_ML_Bootcamp-master/Refactored_Py_DS_ML_Bootcamp-master/07-Pandas-Built-in-Data-Viz/df1',index_col=0)

# %%
type(df1)
# Out:
# pandas.core.frame.DataFrame

# %%
df1.head()
# Out:
#                    A         B         C         D
# 2000-01-01  1.339091 -0.163643 -0.646443  1.041233
# 2000-01-02 -0.774984  0.137034 -0.882716 -2.253382
# 2000-01-03 -0.921037 -0.482943 -0.417100  0.478638
# 2000-01-04 -1.738808 -0.072973  0.056517  0.015085
# 2000-01-05 -0.905980  1.778576  0.381918  0.291436

# %%
df2=pd.read_csv('D:/DataScience_Udemy/Py_DS_ML_Bootcamp-master/Refactored_Py_DS_ML_Bootcamp-master/07-Pandas-Built-in-Data-Viz/df2')

# %%
df2.head()
# Out:
#           a         b         c         d
# 0  0.039762  0.218517  0.103423  0.957904
# 1  0.937288  0.041567  0.899125  0.977680
# 2  0.780504  0.008948  0.557808  0.797510
# 3  0.672717  0.247870  0.264071  0.444358
# 4  0.053829  0.520124  0.552264  0.190008

# %% [markdown]
# # histogram plot with pandas dataframe

# %%
df1['A'].hist()

# %%
df1['A'].hist(bins=30)

# %% [markdown]
#  ***Other method to create Histogram***

# %%
df1['A'].plot(kind='hist',bins=50)

# %% [markdown]
# ***Method-2 to create plot in pandas builtIN data Visualization***
#
# ***Check Below:--->>>***
#
# put whole dataframe or any column of dataframe then **plot** then put types of plot like **hist** in the below example

# %%
df1['A'].plot.hist(bins=30)

# %%
df2
# Out:
#           a         b         c         d
# 0  0.039762  0.218517  0.103423  0.957904
# 1  0.937288  0.041567  0.899125  0.977680
# 2  0.780504  0.008948  0.557808  0.797510
# 3  0.672717  0.247870  0.264071  0.444358
# 4  0.053829  0.520124  0.552264  0.190008
# 5  0.286043  0.593465  0.907307  0.637898
# 6  0.430436  0.166230  0.469383  0.497701
# 7  0.312296  0.502823  0.806609  0.850519
# 8  0.187765  0.997075  0.895955  0.530390
# 9  0.908162  0.232726  0.414138  0.432007

# %% [markdown]
# # Area plot with pandas dataframe
#
# ***Check Below:--->>>>***

# %%
df2.plot.area(alpha=0.4)

# %% [markdown]
# ***In above example parameter "*alpha*" **defines transparency***

# %%
df2['a'].plot.area()

# %% [markdown]
# ***In the above example for one column 'a' area has been plotted***

# %% [markdown]
# # Barplot with pandas dataframe
#
# ***Check Below:--->>>>***

# %%
df2.plot.bar()

# %%
df2['a'].plot.bar()

# %%
df2.plot.bar(stacked=True)

# %% [markdown]
# **** putting argument "*stacked=True*" plots for all the four columns is done together****
#
# **At x=0 value of column 'd' is highest so it's length in stacked plot is largest**

# %%
df2.plot.barh()

# %% [markdown]
# **with plot "barh" we can plot horizontally**
#
# **Check in above example**

# %%
df1['A'].plot.hist(bins=50)

# %%
import matplotlib.pyplot as plt

# %%
df1.index
# Out:
# Index(['2000-01-01', '2000-01-02', '2000-01-03', '2000-01-04', '2000-01-05',
#        '2000-01-06', '2000-01-07', '2000-01-08', '2000-01-09', '2000-01-10',
#        ...
#        '2002-09-17', '2002-09-18', '2002-09-19', '2002-09-20', '2002-09-21',
#        '2002-09-22', '2002-09-23', '2002-09-24', '2002-09-25', '2002-09-26'],
#       dtype='object', length=1000)

# %%
df1.plot.line(x=df1.index,y='B',figsize=(12,3),lw=1)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-45-ce40ab214708> in <module>
# ----> 1 df1.plot.line(x=df1.index,y='B',figsize=(12,3),lw=1)
#
# C:\Anaconda3\lib\site-packages\pandas\plotting\_core.py in line(self, x, y, **kwargs)
#     861             >>> lines = df.plot.line(x='pig', y='horse')
#     862         """
# --> 863         return self(kind="line", x=x, y=y, **kwargs)
#     864
#     865     def bar(self, x=None, y=None, **kwargs):
#
# C:\Anaconda3\lib\site-packages\pandas\plotting\_core.py in __call__(self, *args, **kwargs)
#     757                 if is_integer(x) and not data.columns.holds_integer():
#     758                     x = data_cols[x]
# --> 759                 elif not isinstance(data[x], ABCSeries):
#     760                     raise ValueError("x must be a label or position")
#     761                 data = data.set_index(x)
#
# ...

# %%
x=df1.index
type(x)
# Out:
# pandas.core.indexes.base.Index

# %% [markdown]
# ***Scatter Plots with  pandas dataframe***
#
# ***Check Below:--->>>***

# %%
df1.plot.scatter(x='A',y='B')

# %%
df1['A'].max()
# Out:
# 3.4122362677697287

# %%
df1['B'].max()
# Out:
# 3.1998500209801977

# %%
df1.plot.scatter(x='C',y='D')

# %%
df1.describe()
# Out:
#                  A            B            C            D
# count  1000.000000  1000.000000  1000.000000  1000.000000
# mean     -0.017755     0.048072    -0.001723     0.002432
# std       0.957223     1.004197     0.982384     1.066366
# min      -3.693201    -2.719020    -2.987971    -3.182746
# 25%      -0.639101    -0.652530    -0.690831    -0.676107
# 50%      -0.017793     0.058035    -0.012805    -0.044868
# 75%       0.623478     0.696946     0.706496     0.721699
# max       3.412236     3.199850     3.342484     2.879793

# %% [markdown]
# ***Third column can be shown in plot using color and size***
#
# ***Check Below:---->>>>***

# %%
df1.plot.scatter(x='A',y='B',c='C',cmap='coolwarm')

# %%
df1.plot.scatter(x='A',y='B',s=df1['C']*60)

# %% [markdown]
# ***size argument '**s**' can also be given for third column C***
#
# ***df1['C'] is multiplied by 60 to increase the size***
#
# ***check above example:--->>>***

# %% [markdown]
# # Boxplot with pandas dataframe
#
# ***Chek Below:---->>>***

# %%
df2.plot.box()

# %%
df2['a'].plot.box()

# %% [markdown]
# # Hexbin plots with pandas dataframe
#
# ***Check Below::---->>>***

# %%
df=pd.DataFrame(np.random.randn(1000,2),columns=['a','b'])

# %%
df.head()
# Out:
#           a         b
# 0  1.027531  0.680620
# 1 -1.454382 -0.070209
# 2 -1.028631  1.644136
# 3  1.410773  1.011723
# 4  1.337694  1.300779

# %%
df.plot.hexbin(x='a',y='b',gridsize=15,cmap='coolwarm')

# %% [markdown]
# "***gridsize***" ***helps to increase the size of hexagon in plot***

# %%
df['b'].max()
# Out:
# 3.306023988873416

# %% [markdown]
# ***kernel density plot with pandas dataframe***
#
# ***can be plotted with whole dataframe and with individual columns also***
#
# ***Check Below***:---->>>

# %%
df2.plot.kde()

# %%
df2['a'].plot.kde()
