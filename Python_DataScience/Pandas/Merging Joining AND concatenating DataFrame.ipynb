# %%
import numpy as np 
import pandas as pd

# %%
d1={'A':['A0','A1','A2','A3'],
  'B':['B0','B1','B2','B3'],
  'C':['C0','C1','C2','C3'],
  'D':['D0','D1','D2','D3']}

d2={'A':['A4','A5','A6','A7'],
   'B':['B4','B5','B6','B7'],
   'C':['C5','C6','C7','C8'],
   'D':['D5','D6','D7','D8']}

d3={'A':['A8','A9','A10','A11'],
   'B':['B8','B9','B10','B11'],
   'C':['C8','C9','C10','C11'],
   'D':['D8','D9','D10','D11']}

# %%
df1=pd.DataFrame(d1,index=(0,1,2,3))

# %%
df1
# Out:
#     A   B   C   D
# 0  A0  B0  C0  D0
# 1  A1  B1  C1  D1
# 2  A2  B2  C2  D2
# 3  A3  B3  C3  D3

# %%
df2=pd.DataFrame(d2,index=(4,5,6,7))

# %%
df2
# Out:
#     A   B   C   D
# 4  A4  B4  C5  D5
# 5  A5  B5  C6  D6
# 6  A6  B6  C7  D7
# 7  A7  B7  C8  D8

# %%
df3=pd.DataFrame(d3,index=(8,9,10,11))

# %%
df3
# Out:
#       A    B    C    D
# 8    A8   B8   C8   D8
# 9    A9   B9   C9   D9
# 10  A10  B10  C10  D10
# 11  A11  B11  C11  D11

# %% [markdown]
# ## Concatenating DaatFrames :--->>>
#
# Concatenation work only if axis of all the dataframes are matching on which concatenation is to happen
#
# in concat function Axis=0 is bydefault so concatenation will happen alog the rows
#
# Check Below :--->>>

# %%
pd.concat([df1,df2,df3])
# Out:
#       A    B    C    D
# 0    A0   B0   C0   D0
# 1    A1   B1   C1   D1
# 2    A2   B2   C2   D2
# 3    A3   B3   C3   D3
# 4    A4   B4   C5   D5
# 5    A5   B5   C6   D6
# 6    A6   B6   C7   D7
# 7    A7   B7   C8   D8
# 8    A8   B8   C8   D8
# 9    A9   B9   C9   D9
# 10  A10  B10  C10  D10
# 11  A11  B11  C11  D11

# %% [markdown]
# ## Concatenating along the Columns
#
# Check Below:--->>>

# %%
pd.concat([df1,df2,df3],axis=1)
# Out:
#       A    B    C    D    A    B    C    D    A    B    C    D
# 0    A0   B0   C0   D0  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 1    A1   B1   C1   D1  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 2    A2   B2   C2   D2  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 3    A3   B3   C3   D3  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 4   NaN  NaN  NaN  NaN   A4   B4   C5   D5  NaN  NaN  NaN  NaN
# 5   NaN  NaN  NaN  NaN   A5   B5   C6   D6  NaN  NaN  NaN  NaN
# 6   NaN  NaN  NaN  NaN   A6   B6   C7   D7  NaN  NaN  NaN  NaN
# 7   NaN  NaN  NaN  NaN   A7   B7   C8   D8  NaN  NaN  NaN  NaN
# 8   NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN   A8   B8   C8   D8
# 9   NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN   A9   B9   C9   D9
# 10  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  A10  B10  C10  D10
# 11  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  A11  B11  C11  D11

# %% [markdown]
# ## Example DataFrames :-->>>

# %%
left=pd.DataFrame({'Key':['K0','K1','K2','K3'],
                  'A':['A0','A1','A2','A3'],
                  'B':['B0','B1','B2','B3']})

right=pd.DataFrame({'Key':['K0','K1','K2','K3'],
                   'C':['C0','C1','C2','C3'],
                   'D':['D0','D1','D2','D3']})

# %%
left
# Out:
#   Key   A   B
# 0  K0  A0  B0
# 1  K1  A1  B1
# 2  K2  A2  B2
# 3  K3  A3  B3

# %%
right
# Out:
#   Key   C   D
# 0  K0  C0  D0
# 1  K1  C1  D1
# 2  K2  C2  D2
# 3  K3  C3  D3

# %% [markdown]
# ## Merge function
#
# Merge can work like sql join
#
# check Below:--->>>

# %%
pd.merge(left,right,how='inner',on='Key')
# Out:
#   Key   A   B   C   D
# 0  K0  A0  B0  C0  D0
# 1  K1  A1  B1  C1  D1
# 2  K2  A2  B2  C2  D2
# 3  K3  A3  B3  C3  D3

# %% [markdown]
# ## Merging DatFrame On Multiple Keys
#
# Check Below :--->>>

# %%
left=pd.DataFrame({'Key1':['K0','K0','K1','K2'],
                  'Key2':['K0','K1','K0','K1'],
                  'A':['A0','A1','A2','A3'],
                  'B':['B0','B1','B2','B3']})
right=pd.DataFrame({'Key1':['K0','K1','K1','K2'],
                   'Key2':['k0','k0','k0','k0'],
                   'C':['C0','C1','C2','C3'],
                   'D':['D0','D1','D2','D3']})

# %%
left
# Out:
#   Key1 Key2   A   B
# 0   K0   K0  A0  B0
# 1   K0   K1  A1  B1
# 2   K1   K0  A2  B2
# 3   K2   K1  A3  B3

# %%
right
# Out:
#   Key1 Key2   C   D
# 0   K0   k0  C0  D0
# 1   K1   k0  C1  D1
# 2   K1   k0  C2  D2
# 3   K2   k0  C3  D3

# %%
pd.merge(left,right,on=['Key1','Key2'])
# Out:
# Empty DataFrame
# Columns: [Key1, Key2, A, B, C, D]
# Index: []

# %%
pd.merge(left,right,how='outer',on=['Key1','Key2'])
# Out:
#   Key1 Key2    A    B    C    D
# 0   K0   K0   A0   B0  NaN  NaN
# 1   K0   K1   A1   B1  NaN  NaN
# 2   K1   K0   A2   B2  NaN  NaN
# 3   K2   K1   A3   B3  NaN  NaN
# 4   K0   k0  NaN  NaN   C0   D0
# 5   K1   k0  NaN  NaN   C1   D1
# 6   K1   k0  NaN  NaN   C2   D2
# 7   K2   k0  NaN  NaN   C3   D3

# %%
pd.merge(left,right,how='right',on=['Key1','Key2'])
# Out:
#   Key1 Key2    A    B   C   D
# 0   K0   k0  NaN  NaN  C0  D0
# 1   K1   k0  NaN  NaN  C1  D1
# 2   K1   k0  NaN  NaN  C2  D2
# 3   K2   k0  NaN  NaN  C3  D3

# %% [markdown]
# ## Joining
#
# joining is a convenient method for combining the columns of two potentially diferently indexed DataFrame
#
# into a single result DataFrame

# %%
left=pd.DataFrame({'A':['A0','A1','A2'],
                  'B':['B0','B1','B2']},
                 index=['K0','K1','K2'])
right=pd.DataFrame({'C':['C0','C1','C2'],
                   'D':['D0','D1','D2']},
                  index=['K0','K2','K3'])

# %%
left
# Out:
#      A   B
# K0  A0  B0
# K1  A1  B1
# K2  A2  B2

# %%
right
# Out:
#      C   D
# K0  C0  D0
# K2  C1  D1
# K3  C2  D2

# %% [markdown]
# join by default is left join

# %%
left.join(right)
# Out:
#      A   B    C    D
# K0  A0  B0   C0   D0
# K1  A1  B1  NaN  NaN
# K2  A2  B2   C1   D1

# %%
type(left.join(right))
# Out:
# pandas.core.frame.DataFrame

# %%
left.join(right,how='inner')
# Out:
#      A   B   C   D
# K0  A0  B0  C0  D0
# K2  A2  B2  C1  D1

# %%
left.join(right,how='outer')
# Out:
#       A    B    C    D
# K0   A0   B0   C0   D0
# K1   A1   B1  NaN  NaN
# K2   A2   B2   C1   D1
# K3  NaN  NaN   C2   D2

# %%
left.join(right,how='right')
# Out:
#       A    B   C   D
# K0   A0   B0  C0  D0
# K2   A2   B2  C1  D1
# K3  NaN  NaN  C2  D2
